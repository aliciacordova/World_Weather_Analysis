# %%
import requests
requests.__version__
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_64612/908848449.py in <module>
# ----> 1 import requests
#       2 requests.__version__
#
# ModuleNotFoundError: No module named 'requests'

# %%
import requests
requests.__version__
# Out:
# '2.26.0'
